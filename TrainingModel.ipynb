# %%
# !wget https://www.dropbox.com/s/nilt43hyl1dx82k/dataset.zip?dl=0
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !unzip dataset.zip?dl=0
# Out:
# 'unzip' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from keras.layers import Flatten, Dense
from keras.models import Model
from keras.preprocessing.image import ImageDataGenerator , img_to_array, load_img
from keras.applications.mobilenet import MobileNet, preprocess_input 
from keras.losses import categorical_crossentropy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\Users\MARCEL~1\AppData\Local\Temp/ipykernel_9748/1495411786.py in <module>
#       1 import numpy as np
# ----> 2 import pandas as pd
#       3 import matplotlib.pyplot as plt
#       4
#       5 from keras.layers import Flatten, Dense
#
# ModuleNotFoundError: No module named 'pandas'

# %%
base_model = MobileNet(input_shape = (224, 224, 3), include_top=False)
for layers in base_model.layers:
  layers.trainable = False
x = Flatten()(base_model.output)
x = Dense(units=7, activation = 'softmax')(x)

model = Model(base_model.input, x)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf_no_top.h5
# 17227776/17225924 [==============================] - 0s 0us/step
# 17235968/17225924 [==============================] - 0s 0us/step

# %%
model.compile(optimizer='adam', loss= categorical_crossentropy , metrics=['accuracy']  )

# %%
train_datagen = ImageDataGenerator(
     zoom_range = 0.2, 
     shear_range = 0.2, 
     horizontal_flip=True, 
     rescale = 1./255
)

train_data = train_datagen.flow_from_directory(directory= "/content/train", 
                                               target_size=(224,224), 
                                               batch_size=32,
                                  )


train_data.class_indices
# Out:
# Found 28709 images belonging to 7 classes.
# {'angry': 0,
#  'disgust': 1,
#  'fear': 2,
#  'happy': 3,
#  'neutral': 4,
#  'sad': 5,
#  'surprise': 6}

# %%
val_datagen = ImageDataGenerator(rescale = 1./255 )

val_data = val_datagen.flow_from_directory(directory= "/content/test", 
                                           target_size=(224,224), 
                                           batch_size=32,
                                  )
# Out:
# Found 7178 images belonging to 7 classes.

# %%
# to visualize the images in the traing data denerator 

t_img , label = train_data.next()

#-----------------------------------------------------------------------------
# function when called will prot the images 
def plotImages(img_arr, label):
  """
  input  :- images array 
  output :- plots the images 
  """
  count = 0
  for im, l in zip(img_arr,label) :
    plt.imshow(im)
    plt.title(im.shape)
    plt.axis = False
    plt.show()
    
    count += 1
    if count == 10:
      break

#-----------------------------------------------------------------------------
# function call to plot the images 
plotImages(t_img, label)

# %%
## having early stopping and model check point 

from keras.callbacks import ModelCheckpoint, EarlyStopping

# early stopping
es = EarlyStopping(monitor='val_accuracy', min_delta= 0.01 , patience= 5, verbose= 1, mode='auto')

# model check point
mc = ModelCheckpoint(filepath="best_model.h5", monitor= 'val_accuracy', verbose= 1, save_best_only= True, mode = 'auto')

# puting call back in a list 
call_back = [es, mc]

# %%
hist = model.fit_generator(train_data, 
                           steps_per_epoch= 10, 
                           epochs= 30, 
                           validation_data= val_data, 
                           validation_steps= 8, 
                           callbacks=[es,mc])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Epoch 1/30
# 10/10 [==============================] - ETA: 0s - loss: 21.5955 - accuracy: 0.1937
# Epoch 1: val_accuracy improved from -inf to 0.24609, saving model to best_model.h5
# 10/10 [==============================] - 26s 2s/step - loss: 21.5955 - accuracy: 0.1937 - val_loss: 24.1493 - val_accuracy: 0.2461
# Epoch 2/30
# 10/10 [==============================] - ETA: 0s - loss: 15.3653 - accuracy: 0.2594
# Epoch 2: val_accuracy improved from 0.24609 to 0.33984, saving model to best_model.h5
# 10/10 [==============================] - 21s 2s/step - loss: 15.3653 - accuracy: 0.2594 - val_loss: 9.3459 - val_accuracy: 0.3398
# Epoch 3/30
# 10/10 [==============================] - ETA: 0s - loss: 8.4433 - accuracy: 0.3031
# Epoch 3: val_accuracy improved from 0.33984 to 0.38281, saving model to best_model.h5
# 10/10 [==============================] - 20s 2s/step - loss: 8.4433 - accuracy: 0.3031 - val_loss: 7.3369 - val_accuracy: 0.3828
# Epoch 4/30
# 10/10 [==============================] - ETA: 0s - loss: 6.9888 - accuracy: 0.4031
# Epoch 4: val_accuracy improved from 0.38281 to 0.39453, saving model to best_model.h5
# 10/10 [==============================] - 20s 2s/step - loss: 6.9888 - accuracy: 0.4031 - val_loss: 5.3294 - val_accuracy: 0.3945
# Epoch 5/30
# 10/10 [==============================] - ETA: 0s - loss: 5.8488 - accuracy: 0.4031
# Epoch 5: val_accuracy improved from 0.39453 to 0.40234, saving model to best_model.h5
# 10/10 [==============================] - 21s 2s/step - loss: 5.8488 - accuracy: 0.4031 - val_loss: 6.1898 - val_accuracy: 0.4023
# Epoch 6/30
# 10/10 [==============================] - ETA: 0s - loss: 5.6852 - accuracy: 0.3875
# Epoch 6: val_accuracy improved from 0.40234 to 0.43359, saving model to best_model.h5
# 10/10 [==============================] - 20s 2s/step - loss: 5.6852 - accuracy: 0.3875 - val_loss: 4.8719 - val_accuracy: 0.4336
# Epoch 7/30
# 10/10 [==============================] - ETA: 0s - loss: 4.7013 - accuracy: 0.4500
# Epoch 7: val_accuracy improved from 0.43359 to 0.45312, saving model to best_model.h5
# 10/10 [==============================] - 20s 2s/step - loss: 4.7013 - accuracy: 0.4500 - val_loss: 4.5135 - val_accuracy: 0.4531
# Epoch 8/30
# 10/10 [==============================] - ETA: 0s - loss: 4.7305 - accuracy: 0.4625
# Epoch 8: val_accuracy did not improve from 0.45312
# 10/10 [==============================] - 20s 2s/step - loss: 4.7305 - accuracy: 0.4625 - val_loss: 7.3204 - val_accuracy: 0.3711
# Epoch 9/30
# 10/10 [==============================] - ETA: 0s - loss: 5.2541 - accuracy: 0.4219
# Epoch 9: val_accuracy did not improve from 0.45312
# 10/10 [==============================] - 20s 2s/step - loss: 5.2541 - accuracy: 0.4219 - val_loss: 5.8635 - val_accuracy: 0.3594
# Epoch 10/30
# 10/10 [==============================] - ETA: 0s - loss: 4.9246 - accuracy: 0.4281
# Epoch 10: val_accuracy did not improve from 0.45312
# 10/10 [==============================] - 20s 2s/step - loss: 4.9246 - accuracy: 0.4281 - val_loss: 6.2216 - val_accuracy: 0.4219
# Epoch 11/30
# 10/10 [==============================] - ETA: 0s - loss: 5.7786 - accuracy: 0.4406
# Epoch 11: val_accuracy improved from 0.45312 to 0.46484, saving model to best_model.h5
# 10/10 [==============================] - 20s 2s/step - loss: 5.7786 - accuracy: 0.4406 - val_loss: 4.8267 - val_accuracy: 0.4648
# Epoch 12/30
# 10/10 [==============================] - ETA: 0s - loss: 5.1887 - accuracy: 0.4375
# Epoch 12: val_accuracy improved from 0.46484 to 0.48438, saving model to best_model.h5
# 10/10 [==============================] - 20s 2s/step - loss: 5.1887 - accuracy: 0.4375 - val_loss: 4.2510 - val_accuracy: 0.4844
# Epoch 13/30
# 10/10 [==============================] - ETA: 0s - loss: 5.4158 - accuracy: 0.4469
# Epoch 13: val_accuracy did not improve from 0.48438
# 10/10 [==============================] - 20s 2s/step - loss: 5.4158 - accuracy: 0.4469 - val_loss: 5.4211 - val_accuracy: 0.3984
# Epoch 14/30
# 10/10 [==============================] - ETA: 0s - loss: 5.9603 - accuracy: 0.4313
# Epoch 14: val_accuracy did not improve from 0.48438
# 10/10 [==============================] - 20s 2s/step - loss: 5.9603 - accuracy: 0.4313 - val_loss: 6.5276 - val_accuracy: 0.3828
# Epoch 15/30
# 10/10 [==============================] - ETA: 0s - loss: 6.9964 - accuracy: 0.4062
# Epoch 15: val_accuracy did not improve from 0.48438
# 10/10 [==============================] - 20s 2s/step - loss: 6.9964 - accuracy: 0.4062 - val_loss: 6.7733 - val_accuracy: 0.3906
# Epoch 16/30
# 10/10 [==============================] - ETA: 0s - loss: 6.4622 - accuracy: 0.4031
# Epoch 16: val_accuracy did not improve from 0.48438
# 10/10 [==============================] - 20s 2s/step - loss: 6.4622 - accuracy: 0.4031 - val_loss: 6.7366 - val_accuracy: 0.4219
# Epoch 17/30
# 10/10 [==============================] - ETA: 0s - loss: 5.9357 - accuracy: 0.4313
# Epoch 17: val_accuracy did not improve from 0.48438
# 10/10 [==============================] - 20s 2s/step - loss: 5.9357 - accuracy: 0.4313 - val_loss: 7.4651 - val_accuracy: 0.4453
# Epoch 17: early stopping

# %%
# Loading the best fit model 
from keras.models import load_model
model = load_model("/content/best_model.h5")

# %%
h =  hist.history
h.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.plot(h['accuracy'])
plt.plot(h['val_accuracy'] , c = "red")
plt.title("acc vs v-acc")
plt.show()

# %%
plt.plot(h['loss'])
plt.plot(h['val_loss'] , c = "red")
plt.title("loss vs v-loss")
plt.show()

# %%
# just to map o/p values 
op = dict(zip( train_data.class_indices.values(), train_data.class_indices.keys()))

# %%
# path for the image to see if it predics correct class

path = "/content/surprised_man.jpg"
img = load_img(path, target_size=(224,224) )

i = img_to_array(img)/255
input_arr = np.array([i])
input_arr.shape

pred = np.argmax(model.predict(input_arr))

print(f" the image is of {op[pred]}")

# to display the image  
plt.imshow(input_arr[0])
plt.title("input image")
plt.show()
# Out:
#  the image is of surprise

# %%
import os
import cv2
import numpy as np
from keras.preprocessing import image
import warnings
warnings.filterwarnings("ignore")
from keras.preprocessing.image import load_img, img_to_array 
from keras.models import  load_model
import matplotlib.pyplot as plt
import numpy as np

# load model
model = load_model("/content/best_model.h5")


face_haar_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')


cap = cv2.VideoCapture(0)

while True:
    ret, test_img = cap.read()  # captures frame and returns boolean value and captured image
    if not ret:
        continue
    gray_img = cv2.cvtColor(test_img, cv2.COLOR_BGR2RGB)

    faces_detected = face_haar_cascade.detectMultiScale(gray_img, 1.32, 5)

    for (x, y, w, h) in faces_detected:
        cv2.rectangle(test_img, (x, y), (x + w, y + h), (255, 0, 0), thickness=7)
        roi_gray = gray_img[y:y + w, x:x + h]  # cropping region of interest i.e. face area from  image
        roi_gray = cv2.resize(roi_gray, (224, 224))
        img_pixels = image.img_to_array(roi_gray)
        img_pixels = np.expand_dims(img_pixels, axis=0)
        img_pixels /= 255

        predictions = model.predict(img_pixels)

        # find max indexed array
        max_index = np.argmax(predictions[0])

        emotions = ('angry', 'disgust', 'fear', 'happy', 'sad', 'surprise', 'neutral')
        predicted_emotion = emotions[max_index]

        cv2.putText(test_img, predicted_emotion, (int(x), int(y)), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

    resized_img = cv2.resize(test_img, (1000, 700))
    cv2.imshow('Facial emotion analysis ', resized_img)

    if cv2.waitKey(10) == ord('q'):  # wait until 'q' key is pressed
        break

cap.release()
cv2.destroyAllWindows
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-28b8df704a97> in <module>()
#      20
#      21 while True:
# ---> 22     ret, test_img = cap.read()  # captures frame and returns boolean value and captured image
#      23     if not ret:
#      24         continue
#
# KeyboardInterrupt:
